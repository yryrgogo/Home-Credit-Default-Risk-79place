# %%
from matplotlib_venn import venn3
# %matplotlib inline
#A=1.8, B=0.9,C=0.3,AB=0.5,AC=0.2,BC=0.3,ABC=0.2
from pylab import rcParams

rcParams['figure.figsize'] = 15,15
# rcParams['figure.figsize'] = 200,200
# rcParams['figure.figsize'] = 10,10
# venn3(subsets = (1.8, 0.9, 0.5, 0.3, 0.2, 0.3, 0.2), set_labels = ('A', 'B', 'C'))
# venn3(subsets = (3115, 9355, 1346, 4754, 64, 1346, 1730), set_labels = ('A', 'B', 'C'))
# venn3(subsets = (3235, 9355, 1346, 4754, 64, 1346, 1730))
# venn3(subsets = (85, 3315, 1346, 16, 64, 2944, 1730))
venn3(subsets = (12, 4, 3, 72, 6250, 138, 3073))
# Out:
# /mnt/c/Users/gixo/go/anaconda3/lib/python3.6/site-packages/matplotlib_venn/_venn3.py:117: UserWarning: Bad circle positioning
#   warnings.warn("Bad circle positioning")

# %%
from matplotlib import pyplot as plt
import numpy as np
from matplotlib_venn import venn3, venn3_circles
plt.figure(figsize=(4,4))
v = venn3(subsets=(1, 1, 1, 1, 1, 1, 1), set_labels = ('A', 'B', 'C'))
v.get_patch_by_id('100').set_alpha(0.1)
v.get_patch_by_id('100').set_color('white')
v.get_label_by_id('100').set_text('Unknown')
v.get_label_by_id('A').set_text('Set "A"')
c = venn3_circles(subsets=(1, 1, 1, 1, 1, 1, 1), linestyle='dashed')
c[0].set_lw(1.0)
c[0].set_ls('dotted')
plt.title("Sample Venn diagram")
plt.annotate('Unknown set', xy=v.get_label_by_id('100').get_position() - np.array([0, 0.05]), xytext=(-70,-70),
             ha='center', textcoords='offset points', bbox=dict(boxstyle='round,pad=0.5', fc='gray', alpha=0.1),
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5',color='gray'))
plt.show()

# %%
a = 9335
(16/a)*100
# Out:
# 0.1713979646491698
