# %%
import numpy as np
import pandas as pd
import sys
import re
from glob import glob

import os
HOME = os.path.expanduser('~')
sys.path.append(f"{HOME}/kaggle/github/library/")
import utils
from logger import logger_func
logger = logger_func()
pd.set_option('max_columns', 200)
pd.set_option('max_rows', 200)
# Out:
# 2018-09-05 08:26:17,407 logger 21 [INFO]    [logger_func] start

# %%
# ccb = utils.read_df_pickle(path='../input/credit*.p')
# print(prev.shape)
# prev.query("NAME_CONTRACT_TYPE=='Revolving loans'")
# prev.query("AMT_ANNUTY==0")
p_id = 'SK_ID_PREV'
prev_id = ccb[p_id].drop_duplicates().values
for col in ccb.columns:
    print(col)
# Out:
# SK_ID_PREV
# SK_ID_CURR
# MONTHS_BALANCE
# AMT_BALANCE
# AMT_CREDIT_LIMIT_ACTUAL
# AMT_DRAWINGS_ATM_CURRENT
# AMT_DRAWINGS_CURRENT
# AMT_DRAWINGS_OTHER_CURRENT
# AMT_DRAWINGS_POS_CURRENT
# AMT_INST_MIN_REGULARITY
# AMT_PAYMENT_CURRENT
# AMT_PAYMENT_TOTAL_CURRENT
# AMT_RECEIVABLE_PRINCIPAL
# AMT_RECIVABLE
# AMT_TOTAL_RECEIVABLE
# CNT_DRAWINGS_ATM_CURRENT
# CNT_DRAWINGS_CURRENT
# CNT_DRAWINGS_OTHER_CURRENT
# CNT_DRAWINGS_POS_CURRENT
# CNT_INSTALMENT_MATURE_CUM
# NAME_CONTRACT_STATUS
# SK_DPD
# SK_DPD_DEF

# %%
# pre = utils.read_df_pickle(path='../input/prev*.p')
pre.set_index(p_id).loc[prev_id, :].query('SK_ID_CURR>0')
# Out:
#             SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# SK_ID_PREV
# 2562384       378907.0    Revolving loans      13500.0              0.0
# 1740877       371185.0    Revolving loans       5625.0              0.0
# 1389973       337855.0    Revolving loans       2250.0          45000.0
# 2646502       380010.0    Revolving loans      13500.0         270000.0
# 1079071       171320.0    Revolving loans      16875.0         337500.0
# 2181852       367360.0    Revolving loans      14625.0         292500.0
# 1235299       203885.0    Revolving loans       4500.0              0.0
# 1108284       209660.0    Revolving loans       9000.0         180000.0
# 2740914       340339.0    Revolving loans       2250.0          45000.0
# 1985699       302517.0    Revolving loans       4500.0          90000.0
# 1441883       171537.0    Revolving loans      13500.0         270000.0
# 1864742       303581.0    Revolving loans       3375.0              0.0
# ...

# %%
# len(ccb)
ccb.query(f"AMT_RECIVABLE<-10000")[p_id].drop_duplicates().shape
# Out:
# (293,)

# %%
m = 'MONTHS_BALANCE'
ccb = ccb.sort_values(by=[p_id, 'MONTHS_BALANCE'])
ccb[ccb["CNT_DRAWINGS_ATM_CURRENT"].isnull()]
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 1884129     1000030      361282              -8          0.0
# 1675039     1000031      131335             -16          0.0
# 2012979     1000031      131335             -15          0.0
# 2958108     1000031      131335             -14          0.0
# 685894      1000035      436351              -6          0.0
# 708244      1000035      436351              -5          0.0
# 335532      1000035      436351              -4          0.0
# 521834      1000035      436351              -3          0.0
# 2145598     1000035      436351              -2          0.0
# 2001953     1000077      181153             -12          0.0
# 1431236     1000077      181153             -11          0.0
# 252521      1000077      181153             -10          0.0
# 2739334     1000077      181153              -9          0.0
# 3596307     1000077      181153              -8          0.0
# ...

# %%
p_id = 'SK_ID_PREV'
apa = 'AMT_PAYMENT'
ais = 'AMT_INSTALMENT'
dis = 'DAYS_INSTALMENT'
# display(inst.query(f"{ais}==0"))
# display(inst.query(f"{p_id}==1822101").sort_values(by=[p_id, dis], ascending=[False, False]))
# sys.exit()
# prev_id = inst.query(f"{ais}==0")[p_id].drop_duplicates().values
prev_id = inst[inst[apa].isnull()][p_id].drop_duplicates().values
# print(len(prev_id))
# sys.exit()
inst.set_index(p_id).loc[prev_id, :].sort_values(by=[p_id, dis], ascending=[False, False])
# pre.set_index(p_id).loc[prev_id, :].query("SK_ID_CURR>0")

# %%
prev_id = pos.query("NAME_CONTRACT_STATUS=='Completed' and CNT_INSTALMENT_FUTURE>0")['SK_ID_PREV'].drop_duplicates()
# pos.query("NAME_CONTRACT_STATUS=='XNA'")
pos.set_index('SK_ID_PREV').loc[prev_id, :].sort_values(by=['SK_ID_PREV', 'MONTHS_BALANCE'], ascending=[True, False])

# %%
# pos['NAME_CONTRACT_STATUS'].drop_duplicates(keep='first')
# pos['NAME_CONTRACT_STATUS'].value_counts()
# prev_id = pos.query("NAME_CONTRACT_STATUS=='Approved'")['SK_ID_PREV'].drop_duplicates().values
# pos.set_index('SK_ID_PREV').loc[prev_id, :].sort_values(by=['SK_ID_CURR', 'SK_ID_PREV', 'MONTHS_BALANCE'], ascending=[True, True, False])
pos.query("SK_ID_PREV=='1870980'").sort_values(by=['SK_ID_PREV', 'MONTHS_BALANCE'], ascending=[True, False])
# pos[pos['CNT_INSTALMENT'].isnull()]

# %%
pos.query("NAME_CONTRACT_STATUS!='Signed' and NAME_CONTRACT_STATUS!='Approved'").shape

# %%
# df = df.sort_values(by=['SK_ID_CURR', 'SK_ID_PREV', 'NUM_INSTALMENT_NUMBER'])
tmp = tmp.sort_values(by=['AMT_INSTALMENT'], ascending=False)
tmp
